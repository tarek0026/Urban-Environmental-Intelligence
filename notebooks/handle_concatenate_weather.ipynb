# %%
import pandas as pd

# %%
df1=pd.read_csv("../Data/integrated/airquality_greenspace.csv")

# %%
df1.isna().sum()
# Out:
# Unnamed: 0     0
# City           0
# Date           0
# PM2.5          0
# PM10           0
# O3             0
# NO2            0
# CO             0
# SO2            0
# Green_Space    0
# dtype: int64

# %%
df_cairo=pd.read_csv("../Data/raw/weather_cairo_2023.csv")
df_cairo=df_cairo.iloc[1:,]
df_cairo.isna().sum()
# Out:
#          Date  Temperature_mean  Temperature_max   Humidity  Wind_speed  \
# 1  2023-01-01         15.888889             20.0  75.333333    8.511111
# 2  2023-01-02         16.044444             21.0  70.844444    7.888889
#
#       Pressure   City
# 1  1007.247111  Cairo
# 2  1006.393556  Cairo

# %%
df_dubai=pd.read_csv("../Data/raw/weather_dubai_2023.csv")
df_dubai=df_dubai.iloc[1:,]
df_dubai.isna().sum()
# Out:
# Date                0
# Temperature_mean    0
# Temperature_max     0
# Humidity            0
# Wind_speed          0
# Pressure            0
# City                0
# dtype: int64

# %%
df_paris=pd.read_csv("../Data/raw/weather_paris_2023.csv")
df_paris=df_paris.iloc[1:,]
df_paris.isna().sum()
# Out:
# Date                0
# Temperature_mean    0
# Temperature_max     0
# Humidity            0
# Wind_speed          0
# Pressure            0
# City                0
# dtype: int64

# %%
df_tokyo=pd.read_csv("../Data/raw/weather_tokyo_2023.csv")
df_tokyo=df_tokyo.iloc[1:,]
df_tokyo.isna().sum()
# Out:
# Date                0
# Temperature_mean    0
# Temperature_max     0
# Humidity            0
# Wind_speed          0
# Pressure            0
# City                0
# dtype: int64

# %%
df_nairobi=pd.read_csv("../Data/raw/weather_nairobi_2023.csv")
df_nairobi=df_nairobi.iloc[1:,]
df_nairobi.isna().sum()
# Out:
# Date                0
# Temperature_mean    0
# Temperature_max     0
# Humidity            0
# Wind_speed          0
# Pressure            0
# City                0
# dtype: int64

# %%
df_london=pd.read_csv("../Data/raw/weather_london_2023.csv")
df_london.isna().sum()
# Out:
# Date                0
# Temperature_mean    0
# Temperature_max     0
# Humidity            0
# Wind_speed          0
# Pressure            0
# City                0
# dtype: int64

# %%
df_newyork=pd.read_csv("../Data/raw/weather_newyork_2023.csv")

# %%
df_newyork.isnull().sum()
# Out:
# Date                 0
# Temperature_mean    28
# Temperature_max     28
# Humidity            28
# Wind_speed           0
# Pressure             0
# City                 0
# dtype: int64

# %%
df_newyork.bfill(inplace=True)

# %%
df_newyork.isna().sum()
# Out:
# Date                0
# Temperature_mean    0
# Temperature_max     0
# Humidity            0
# Wind_speed          0
# Pressure            0
# City                0
# dtype: int64

# %%
df_all_weather = pd.concat([
    df_london,
    df_cairo,
    df_dubai,
    df_nairobi,
    df_tokyo,
    df_paris,
    df_newyork
], ignore_index=True)

# %%
df_all_weather.to_csv("../Data/integrated/weather_all_cities_2023.csv", index=False)
