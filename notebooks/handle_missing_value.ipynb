# %%
import pandas as pd

# %%
df1=pd.read_csv("../Data/integrated/airquality_greenspace.csv")

# %%
df1.isna().sum()
# Out:
# Unnamed: 0     0
# City           0
# Date           0
# PM2.5          0
# PM10           0
# O3             0
# NO2            0
# CO             0
# SO2            0
# Green_Space    0
# dtype: int64

# %%
df2=pd.read_csv("../Data/raw/weather_cairo.csv")
df2.isna().sum()
# Out:
# Date           0
# Temperature    0
# humidity       0
# wind_speed     0
# City           0
# dtype: int64

# %%
df3=pd.read_csv("../Data/raw/dubai_weather_2023.csv")
df3.isna().sum()
# Out:
# Date           0
# Temperature    0
# humidity       0
# wind_speed     0
# City           0
# dtype: int64

# %%
df4=pd.read_csv("../Data/raw/paris_weather_2023.csv")
df4.isna().sum()
# Out:
# Date           0
# Temperature    0
# humidity       0
# wind_speed     0
# City           0
# dtype: int64

# %%
df5=pd.read_csv("../Data/raw/tokyo_weather_2023.csv")
df5.isna().sum()
# Out:
# Date           0
# Temperature    0
# humidity       0
# wind_speed     0
# City           0
# dtype: int64

# %%
df6=pd.read_csv("../Data/raw/weather_nairobi_london.csv")
d6.isna().sum()
# Out:
# Date           0
# Temperature    0
# humidity       0
# wind_speed     0
# City           0
# dtype: int64

# %%
df7=pd.read_csv("../Data/raw/newyork_weather_2023.csv")
df7.isna().sum()
# Out:
# Date           0
# Temperature    0
# humidity       0
# wind_speed     0
# City           0
# dtype: int64

# %%
df_all_weather = pd.concat([
    df2,
    df3,
    df4,
    df5,
    df6,
    df7,
], ignore_index=True)

# %%
df_all_weather.to_csv("../Data/integrated/weather_all_cities_2023.csv", index=False)
