# %% [markdown]
# # Green Space vs Air Quality Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Data/final/environment_data.csv')
df.head()
# Out:
#     City        Date      PM2.5       PM10         O3        NO2          CO  \
# 0  Cairo  2023-01-01  36.337500  60.341667  33.333333  36.100000  337.416667
# 1  Cairo  2023-01-02  49.379167  78.937500  18.625000  46.704167  442.000000
# 2  Cairo  2023-01-03  34.066667  51.825000  24.583333  44.612500  387.041667
# 3  Cairo  2023-01-04  30.737500  43.029167  38.958333  37.420833  322.166667
# 4  Cairo  2023-01-05  23.145833  34.125000  29.041667  48.162500  415.166667
#
#          SO2  Green_Space  Temperature_mean  Temperature_max   Humidity  \
# 0  34.795833           53         15.888889             20.0  75.333333
# 1  55.141667           53         16.044444             21.0  70.844444
# 2  48.670833           53         15.288889             19.0  75.911111
# 3  42.025000           53         15.777778             19.0  78.377778
# 4  50.412500           53         16.136364             19.0  61.795455
#
#    Wind_speed     Pressure  Electricity Consumption     Source  isWeekend  \
# 0    8.511111  1007.247111             3.583944e+08  estimated          0
# 1    7.888889  1006.393556             4.010897e+08  estimated          0
# 2    6.644444  1006.458667             4.154422e+08  estimated          0
# 3    7.022222  1007.377111             4.332206e+08  estimated          0
# 4    5.704545  1008.101818             4.017179e+08  estimated          0
#
#    Season
# 0  Winter
# 1  Winter
# 2  Winter
# 3  Winter
# 4  Winter

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2548 entries, 0 to 2547
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   City               627 non-null    str
#  1   Date               627 non-null    str
#  2   PM2.5              627 non-null    float64
#  3   PM10               627 non-null    float64
#  4   O3                 627 non-null    float64
#  5   NO2                627 non-null    float64
#  6   CO                 627 non-null    float64
#  7   SO2                627 non-null    float64
#  8   Green_Space        627 non-null    float64
#  9   Air_Quality_Score  627 non-null    float64
# dtypes: float64(8), str(2)
# memory usage: 199.2 KB
#             PM2.5        PM10          O3         NO2           CO  \
# count  627.000000  627.000000  627.000000  627.000000   627.000000
# mean    19.755688   31.679552   43.670986   40.804107   361.544125
# std     12.245439   22.073232   21.946516   28.020408   194.057201
# min      3.929167    5.641667    1.416667    1.841667   118.541667
# 25%     10.502083   15.485417   25.937500   18.527083   225.125000
# 50%     16.870833   24.862500   44.791667   36.100000   326.958333
# 75%     25.729167   42.660417   59.875000   55.275000   463.270833
# max     81.337500  143.375000  107.000000  180.391667  1919.208333
#
#               SO2  Green_Space  Air_Quality_Score
# count  627.000000   627.000000         627.000000
# mean    15.689793   105.052632         513.144252
# std     20.563514    46.085857         229.462057
# min      1.220833    51.000000         213.850000
# 25%      3.662500    53.000000         340.683333
# 50%      5.762500   120.000000         486.558333
# 75%     20.764583   162.000000         618.487500
# max    144.008333   164.000000        2134.537500

# %% [markdown]
# ## Correlation Heatmap

# %%
corr_matrix = df[['PM2.5', 'PM10', 'O3', 'NO2', 'CO', 'SO2', 'Green_Space']].corr()

plt.figure(figsize=(10,7))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Between Green Space and Air Quality Components')
plt.show()

# %% [markdown]
# Negative correlations between green space and pollutants may indicate that cities with more green areas experience better air quality.
#
# Strong positive correlations between pollutants suggest polluted cities often experience multiple pollutants simultaneously.

# %% [markdown]
# ## Scatter Plots: Green Space vs Air Pollutants

# %%
pollutants = ['PM2.5', 'PM10', 'O3', 'NO2', 'CO', 'SO2']

plt.figure(figsize=(18,12))

for i, pollutant in enumerate(pollutants, 1):
    plt.subplot(2,3,i)
    sns.scatterplot(data=df, x='Green_Space', y=pollutant, alpha=0.6)
    sns.regplot(data=df, x='Green_Space', y=pollutant, scatter=False, color='blue')
    plt.title(f'Green Space vs {pollutant}')

plt.tight_layout()
plt.show()

# %% [markdown]
# In most cases, higher green space coverage appears associated with lower pollutant concentrations.

# %% [markdown]
# ## Average Pollutant Levels by City

# %%
city_avg = df.groupby('City')[['PM2.5', 'PM10', 'O3', 'NO2', 'CO', 'SO2']].mean()

city_avg.plot(kind='bar', figsize=(15,8))
plt.title('Average Air Pollutant Levels by City')
plt.ylabel('Average Pollutant Level')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Some cities show higher pollution levels across multiple pollutants, indicating worse overall air quality.

# %% [markdown]
# ## Combined Air Quality Score

# %%
df['Air_Quality_Score'] = (df['PM2.5'] + df['PM10'] + df['O3'] + df['NO2'] + df['CO'] + df['SO2'])

df[['City', 'Air_Quality_Score']].head()
# Out:
#     City  Air_Quality_Score
# 0  Cairo         538.325000
# 1  Cairo         690.787500
# 2  Cairo         590.800000
# 3  Cairo         514.337500
# 4  Cairo         600.054167

# %% [markdown]
# The combined air quality score combines all air pollutants into a single indicator. Higher scores indicate worse overall air quality.

# %% [markdown]
# ## Green Space vs Combined Air Quality Score

# %%
plt.figure(figsize=(10,6))

sns.scatterplot(
    data=df,
    x='Green_Space',
    y='Air_Quality_Score',
    alpha=0.6
)

sns.regplot(
    data=df,
    x='Green_Space',
    y='Air_Quality_Score',
    scatter=False,
    color='red'
)

plt.title('Green Space vs Combined Air Quality Score')
plt.xlabel('Green Space')
plt.ylabel('Air Quality Score')

plt.show()

# %% [markdown]
# A downward trend suggests that increased green space may contribute to improved overall air quality.

# %% [markdown]
# # Final Conclusion
#
# - Several pollutants show negative relationships with green space.
# - Cities with larger green areas often demonstrate lower pollution levels.
# - The combined air quality score generally decreases as green space increases.
# - Air pollutants tend to rise together in heavily polluted cities.
#
# Overall, increasing urban green space may contribute to healthier environmental conditions and reduced air pollution exposure.
